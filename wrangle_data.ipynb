# %%
# Install libraries
# !pip install Pandas
# !pip install GeoPandas

# %%
# Add Libraries
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Once necissary libraries are configured we can begin cleaning the data.

# %%
# Read the socioeconomic data into a DataFrame and preview the first 10 rows.
neighbourhood_profiles_df = pd.read_csv("Data/Toronto_neighbourhood_profiles_2021.csv")
neighbourhood_profiles_df.head()
# Out:
#                                   Neighbourhood Name  \
# 0                               Neighbourhood Number
# 1                              TSNS 2020 Designation
# 2  Total - Age groups of the population - 25% sam...
# 3                                      0 to 14 years
# 4                                       0 to 4 years
#
#                  West Humber-Clairville Mount Olive-Silverstone-Jamestown  \
# 0                                     1                                 2
# 1  Not an NIA or Emerging Neighbourhood    Neighbourhood Improvement Area
# 2                                 33300                             31345
# 3                                  4295                              5690
# 4                                  1460                              1650
#
#      Thistletown-Beaumond Heights                       Rexdale-Kipling  \
# 0                               3                                     4
# ...

# %%
#Transpose the df

# Set the first row as column headers
neighbourhood_profiles_df.columns = neighbourhood_profiles_df.iloc[0]
neighbourhood_profiles_df = neighbourhood_profiles_df.drop(0)

# Reset the index to preserve the neighbourhood names
neighbourhood_profiles_df = neighbourhood_profiles_df.reset_index(drop=True)

# Transpose the DataFrame
transposed_df = neighbourhood_profiles_df.T
transposed_df.reset_index(inplace = True)

# Rename the 'index' column to 'Neighbourhood Name' to preserve the neighbourhood names
transposed_df.rename(columns={'index': 'Neighbourhood Name'}, inplace=True)

# Save the transposed DataFrame to a CSV
transposed_df.to_csv('transposed_neighbourhood_data.csv', index=False)

# Preview the transposed DataFrame
transposed_df.head()
# Out:
#                    0                                     1     \
# 0  Neighbourhood Number                 TSNS 2020 Designation
# 1                     1  Not an NIA or Emerging Neighbourhood
# 2                     2        Neighbourhood Improvement Area
# 3                     3        Neighbourhood Improvement Area
# 4                     4  Not an NIA or Emerging Neighbourhood
#
#                                                 2                3     \
# 0  Total - Age groups of the population - 25% sam...    0 to 14 years
# 1                                              33300             4295
# 2                                              31345             5690
# 3                                               9850             1495
# 4                                              10375             1575
#
#                4                 5                   6                 7     \
# 0      0 to 4 years      5 to 9 years      10 to 14 years    15 to 64 years
# ...

# %%
neighbourhood_profiles_df.to_csv("transposed_df.csv", index = False)

# %%
# Filter data for ID, Name, Median Income
# filtered_df = neighbourhood_profiles_df[["Neighbourhood Number", "Neighbourhood Name", "Median total income in 2020  among recipients ($)"]]
# filtered_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Filter data for ID, Name, Median Income
# ----> 2 filtered_df = neighbourhood_profiles_df[["Neighbourhood Number", "Neighbourhood Name", "Median total income in 2020  among recipients ($)"]]
#       3 filtered_df.head()
#
# File ~/Documents/Career/Projects/Toronto_UHI_Analysis/.venv/lib/python3.9/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/Career/Projects/Toronto_UHI_Analysis/.venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
# ...
